# %%
import pandas as pd
import numpy as np
from scipy import stats
import os
import sys

# Get the current directory
current_dir = os.getcwd()

# Add the src directory to the Python path
src_path = os.path.join(current_dir, 'src')
sys.path.append(src_path)
from src.bargaining_analysis.analysis_03042025.clean_data import clean_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 13
#      11 src_path = os.path.join(current_dir, 'src')
#      12 sys.path.append(src_path)
# ---> 13 from src.bargaining_analysis.analysis_03042025.clean_data import clean_data
#
# ModuleNotFoundError: No module named 'src'

# %%
# Import the raw data
raw_data = pd.read_csv('/Users/nicolasroever/Dropbox/Promotion/Bargaining/bargaining_experiment_analysis/src/bargaining_analysis/data/Data_Collection13_02_2025/all_apps_wide-2025-02-13.csv')  # Replace with your actual raw data file path

# Clean the data
df_clean = clean_data(raw_data)
