# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/nicolasroever/Dropbox/Promotion/Bargaining/bargaining_experiment_analysis/bld/data/merged_data_full.csv")

# %%
df_player_1 = df[(df["session_id"] == "8jp2clvt") & (df["participant_label"] == "dE5arGFL")]
